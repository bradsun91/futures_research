# %% [markdown]
# ## Tushare为金融数据分析提供便捷、快速的接口，与投研和量化策略无缝对接

# %%
# !pip install tushare
# Out:
# Collecting tushare
#   Downloading tushare-1.2.54-py3-none-any.whl (213 kB)
# Processing c:\users\huyia\appdata\local\pip\cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472\bs4-0.0.1-cp37-none-any.whl
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda_zzh\lib\site-packages (from tushare) (2.22.0)
# Requirement already satisfied: lxml>=3.8.0 in d:\anaconda_zzh\lib\site-packages (from tushare) (4.5.0)
# Collecting websocket-client>=0.57.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting simplejson>=3.16.0
#   Downloading simplejson-3.17.0-cp37-cp37m-win_amd64.whl (73 kB)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda_zzh\lib\site-packages (from bs4>=0.0.1->tushare) (4.8.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda_zzh\lib\site-packages (from requests>=2.0.0->tushare) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda_zzh\lib\site-packages (from requests>=2.0.0->tushare) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda_zzh\lib\site-packages (from requests>=2.0.0->tushare) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda_zzh\lib\site-packages (from requests>=2.0.0->tushare) (3.0.4)
# Requirement already satisfied: six in d:\anaconda_zzh\lib\site-packages (from websocket-client>=0.57.0->tushare) (1.14.0)
# Requirement already satisfied: soupsieve>=1.2 in d:\anaconda_zzh\lib\site-packages (from beautifulsoup4->bs4>=0.0.1->tushare) (1.9.5)
# Installing collected packages: bs4, websocket-client, simplejson, tushare
# Successfully installed bs4-0.0.1 simplejson-3.17.0 tushare-1.2.54 websocket-client-0.57.0

# %%
import tushare as ts
print(ts.__version__)
# Out:
# 1.2.54

# %%
token = "8ef5ec61cdd848715c57c11d58dd71da1271f76b2420d2bac8aef123"

# %%
import os
#os.listdir()
import pandas as pd
futures_info = pd.read_excel("商品期货信息汇总.xlsx")
futures_info
# Out:
#            交易所 品种大类别 品种子类别  Unnamed: 3                 品种       收盘价格  开盘价格  \
# 0      上海期货交易所    金属   贵金属        11.0                 沪金     278.55   NaN
# 1      大连商品交易所   工业品   NaN        16.0                 焦炭    1972.00   NaN
# 2      大连商品交易所   工业品   NaN        18.0                铁矿石     514.00   NaN
# 3      郑州商品交易所  非农产品   NaN        25.0            动力煤（郑煤）     565.00   NaN
# 4      大连商品交易所   工业品   NaN        17.0                 焦煤    1193.00   NaN
# 5      上海期货交易所    金属   贵金属        12.0                  银    3529.00   NaN
# 6      上海期货交易所    金属   NaN         7.0                 螺纹    3658.00   NaN
# 7      上海期货交易所    金属   NaN         8.0               热轧卷板    3633.00   NaN
# 8      上海期货交易所    金属  有色金属        15.0                 沪锡  146852.00   NaN
# 9      上海期货交易所  能源化工   NaN        22.0                 橡胶   11795.00   NaN
# 10     郑州商品交易所  非农产品   NaN        23.0                 郑醇    2511.00   NaN
# 11     上海期货交易所  能源化工   NaN        26.0                 沥青    2830.00   NaN
# 12     大连商品交易所   农业品   NaN        28.0                 豆粕    2678.00   NaN
# 13     郑州商品交易所   农产品   NaN        29.0        菜籽粕（简称“菜粕”）    2181.00   NaN
# 14     大连商品交易所   农业品   NaN        30.0                 豆油    5604.00   NaN
# 15     大连商品交易所   农业品   NaN        31.0              棕榈（油）    4682.00   NaN
# 16     大连商品交易所   农业品   NaN        33.0              黄大豆1号    3440.00   NaN
# 17     大连商品交易所   农业品   NaN        34.0                黄玉米    1843.00   NaN
# 18     郑州商品交易所   农产品   NaN        35.0                 苹果   10810.00   NaN
# 19     郑州商品交易所   农产品   NaN        37.0  菜籽油（简称“菜油”）（“郑油”）    6546.00   NaN
# 20     郑州商品交易所   农产品   NaN        38.0        白砂糖(简称“白糖”）    4797.00   NaN
# 21     上海期货交易所    金属  有色金属         9.0                 沪铜   49090.00   NaN
# 22     上海期货交易所    金属  有色金属        10.0                  铝   13650.00   NaN
# 23     上海期货交易所    金属  有色金属        14.0                  锌   20850.00   NaN
# 24     大连商品交易所   工业品    化工        19.0       线型低密度聚乙烯（塑料）    8635.00   NaN
# 25     大连商品交易所   工业品    化工        20.0          聚氯乙烯（PVC）    6430.00   NaN
# 26     大连商品交易所   工业品    化工        21.0          \t聚丙烯（PP）    8723.00   NaN
# 27     郑州商品交易所  非农产品   NaN        24.0        精对苯二甲酸（PTA）    6012.00   NaN
# 28     大连商品交易所   农业品   NaN        32.0                 鸡蛋    3516.00   NaN
# 29     郑州商品交易所   农产品   NaN        36.0                 棉花   24300.00   NaN
# 30     上海期货交易所    金属  有色金属        13.0                 沪镍   91820.00   NaN
# 31     上海期货交易所  能源化工   NaN        27.0                 纸浆    5320.00   NaN
# 32     上海期货交易所    金属   NaN         NaN                  铅        NaN   NaN
# 33  上海国际能源交易中心  能源化工   NaN         NaN                 原油        NaN   NaN
# 34     上海期货交易所  能源化工   NaN         NaN                 燃油        NaN   NaN
# 35     郑州商品交易所  非农产品   NaN         NaN                 玻璃        NaN   NaN
# 36     大连商品交易所   工业品   NaN         NaN                乙二醇        NaN   NaN
# 37     郑州商品交易所  非农产品   NaN         NaN                 锰硅        NaN   NaN
# 38     郑州商品交易所  非农产品   NaN         NaN                 硅铁        NaN   NaN
# 39     大连商品交易所   农业品   NaN         NaN               玉米淀粉        NaN   NaN
# 40         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 41         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 42         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 43         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 44         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 45         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 46         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 47         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 48         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 49         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 50         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 51         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 52         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 53         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 54         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 55         NaN   NaN   NaN         NaN                NaN        NaN   NaN
# 56         NaN   NaN   NaN         NaN                 淀粉        NaN   NaN
#
#     最低价  最高价  成交量  ...      一手保证金       一手价值  \
# 0   NaN  NaN  NaN  ...   19498.50   278550.0
# 1   NaN  NaN  NaN  ...   15776.00   197200.0
# 2   NaN  NaN  NaN  ...    4112.00    51400.0
# 3   NaN  NaN  NaN  ...    3390.00    56500.0
# 4   NaN  NaN  NaN  ...    6442.20    71580.0
# 5   NaN  NaN  NaN  ...    3176.10    52935.0
# 6   NaN  NaN  NaN  ...    2926.40    36580.0
# 7   NaN  NaN  NaN  ...    2906.40    36330.0
# 8   NaN  NaN  NaN  ...  102796.40  1468520.0
# 9   NaN  NaN  NaN  ...   14154.00   117950.0
# 10  NaN  NaN  NaN  ...    1757.70    25110.0
# 11  NaN  NaN  NaN  ...    2547.00    28300.0
# 12  NaN  NaN  NaN  ...    1339.00    26780.0
# 13  NaN  NaN  NaN  ...    1090.50    21810.0
# 14  NaN  NaN  NaN  ...    3362.40    56040.0
# 15  NaN  NaN  NaN  ...    2341.00    46820.0
# 16  NaN  NaN  NaN  ...    2408.00    34400.0
# 17  NaN  NaN  NaN  ...     921.50    18430.0
# 18  NaN  NaN  NaN  ...   11891.00   108100.0
# 19  NaN  NaN  NaN  ...    3273.00    65460.0
# 20  NaN  NaN  NaN  ...    2398.50    47970.0
# 21  NaN  NaN  NaN  ...   12272.50   245450.0
# 22  NaN  NaN  NaN  ...    6825.00    68250.0
# 23  NaN  NaN  NaN  ...    7297.50   104250.0
# 24  NaN  NaN  NaN  ...    2158.75    43175.0
# 25  NaN  NaN  NaN  ...    2250.50    32150.0
# 26  NaN  NaN  NaN  ...    3053.05    43615.0
# 27  NaN  NaN  NaN  ...    1803.60    30060.0
# 28  NaN  NaN  NaN  ...    1406.40    17580.0
# 29  NaN  NaN  NaN  ...    6075.00   121500.0
# 30  NaN  NaN  NaN  ...    9182.00        NaN
# 31  NaN  NaN  NaN  ...       0.00        NaN
# 32  NaN  NaN  NaN  ...        NaN        NaN
# 33  NaN  NaN  NaN  ...        NaN        NaN
# 34  NaN  NaN  NaN  ...        NaN        NaN
# 35  NaN  NaN  NaN  ...        NaN        NaN
# 36  NaN  NaN  NaN  ...        NaN        NaN
# 37  NaN  NaN  NaN  ...        NaN        NaN
# 38  NaN  NaN  NaN  ...        NaN        NaN
# 39  NaN  NaN  NaN  ...        NaN        NaN
# 40  NaN  NaN  NaN  ...        NaN        NaN
# 41  NaN  NaN  NaN  ...        NaN        NaN
# 42  NaN  NaN  NaN  ...        NaN        NaN
# 43  NaN  NaN  NaN  ...        NaN        NaN
# 44  NaN  NaN  NaN  ...        NaN        NaN
# 45  NaN  NaN  NaN  ...        NaN        NaN
# 46  NaN  NaN  NaN  ...        NaN        NaN
# 47  NaN  NaN  NaN  ...        NaN        NaN
# 48  NaN  NaN  NaN  ...        NaN        NaN
# 49  NaN  NaN  NaN  ...        NaN        NaN
# 50  NaN  NaN  NaN  ...        NaN        NaN
# 51  NaN  NaN  NaN  ...        NaN        NaN
# 52  NaN  NaN  NaN  ...        NaN        NaN
# 53  NaN  NaN  NaN  ...        NaN        NaN
# 54  NaN  NaN  NaN  ...        NaN        NaN
# 55  NaN  NaN  NaN  ...        NaN        NaN
# 56  NaN  NaN  NaN  ...        NaN        NaN
#
#                                         手续费  交易单位（contractunit）/手OR每点价值/乘数  \
# 0                                     10元/手                         1000.0
# 1                               成交金额的万分之0.6                          100.0
# 2   1月、5月、9月合约：成交金额万分之0.6；其它合约：成交金额的万分之0.06                          100.0
# 3                                      4元/手                          100.0
# 4                               成交金额的万分之0.6                           60.0
# 5                              成交金额的万分之0.05                           15.0
# 6                                    万分之0.1                           10.0
# 7                               成交金额的万分之0.1                           10.0
# 8                                      3元/手                           10.0
# 9                                  万分之0.045                           10.0
# 10                                 2.00 元/手                           10.0
# 11                                    0.1%%                           10.0
# 12    1、5、9合约：成交金额万分之0.6\n其它合约：成交金额的万分之0.06                           10.0
# 13                        1.5元/手，平今仓0.75元/手                           10.0
# 14                                   2.5元/手                           10.0
# 15                                   2.5元/手                           10.0
# 16                                     2元一手                           10.0
# 17                1、5、9合约：1.2元/手；其他合约0.2元/手                           10.0
# 18                                    20元/手                           10.0
# 19                             2元/手，平今仓1元/手                           10.0
# 20                           3元/手，平今仓1.5元/手                           10.0
# 21                                  万分之0.05                            5.0
# 22                                     3元/手                            5.0
# 23                                     3元/手                            5.0
# 24                                     2元/手                            5.0
# 25                                     2元/手                            5.0
# 26                              成交金额的万分之0.6                            5.0
# 27                            6元/手，平今仓12元/手                            5.0
# 28                              成交金额的万分之1.5                            5.0
# 29                          4.3元/手,平今仓10元/手                            5.0
# 30                                     6元/手                            1.0
# 31                                      NaN                            NaN
# 32                                      NaN                            NaN
# 33                                      NaN                            NaN
# 34                                      NaN                            NaN
# 35                                      NaN                            NaN
# 36                                      NaN                            NaN
# 37                                      NaN                            NaN
# 38                                      NaN                            NaN
# 39                                      NaN                            NaN
# 40                                      NaN                            NaN
# 41                                      NaN                            NaN
# 42                                      NaN                            NaN
# 43                                      NaN                            NaN
# 44                                      NaN                            NaN
# 45                                      NaN                            NaN
# 46                                      NaN                            NaN
# 47                                      NaN                            NaN
# 48                                      NaN                            NaN
# 49                                      NaN                            NaN
# 50                                      NaN                            NaN
# 51                                      NaN                            NaN
# 52                                      NaN                            NaN
# 53                                      NaN                            NaN
# 54                                      NaN                            NaN
# 55                                      NaN                            NaN
# 56                                      NaN                            NaN
#
#     最小变动价位（元/吨）          报价单位  \
# 0          0.05      元（人民币）/吨
# 1           0.5      元（人民币）/吨
# 2           0.5      元（人民币）/吨
# 3           0.2      元（人民币）/吨
# 4           0.5      元（人民币）/吨
# 5             1     元（人民币）/千克
# 6             1      元（人民币）/吨
# 7             1      元（人民币）/吨
# 8             1      元（人民币）/吨
# 9             5      元（人民币）/吨
# 10            1    \t元（人民币）/吨
# 11          NaN           NaN
# 12            1    \t元（人民币）/吨
# 13            1      元（人民币）/吨
# 14            2      元（人民币）/吨
# 15            2      元（人民币）/吨
# 16            1      元（人民币）/吨
# 17            1      元（人民币）/吨
# 18            1      元（人民币）/吨
# 19            2      元（人民币）/吨
# 20            1      元（人民币）/吨
# 21           10      元（人民币）/吨
# 22            5      元（人民币）/吨
# 23            5      元（人民币）/吨
# 24            5      元（人民币）/吨
# 25            5      元（人民币）/吨
# 26            1      元（人民币）/吨
# 27            2      元（人民币）/吨
# 28     1元/500千克  元（人民币）/500千克
# 29            5      元（人民币）/吨
# 30           10      元（人民币）/吨
# 31          NaN           NaN
# 32          NaN           NaN
# 33          NaN           NaN
# 34          NaN           NaN
# 35          NaN           NaN
# 36          NaN           NaN
# 37          NaN           NaN
# 38          NaN           NaN
# 39          NaN           NaN
# 40          NaN           NaN
# 41          NaN           NaN
# 42          NaN           NaN
# 43          NaN           NaN
# 44          NaN           NaN
# 45          NaN           NaN
# 46          NaN           NaN
# 47          NaN           NaN
# 48          NaN           NaN
# 49          NaN           NaN
# 50          NaN           NaN
# 51          NaN           NaN
# 52          NaN           NaN
# 53          NaN           NaN
# 54          NaN           NaN
# 55          NaN           NaN
# 56          NaN           NaN
#
#                                                合约在线地址  \
# 0   https://finance.sina.com.cn/futures/quotes/AU1...
# 1   http://www.dce.com.cn/dalianshangpin/yw/fw/ywc...
# 2   http://www.dce.com.cn/dalianshangpin/sspz/4874...
# 3   http://www.czce.com.cn/cn/sspz/dlm/H770212inde...
# 4   http://www.dce.com.cn/dalianshangpin/sspz/4874...
# 5   http://www.shfe.com.cn/products/ag/\nhttps://f...
# 6   http://www.shfe.com.cn/products/rb/\nhttp://ww...
# 7   http://www.shfe.com.cn/products/hc/\nhttps://f...
# 8   https://finance.sina.com.cn/futures/quotes/SN1...
# 9   http://www.shfe.com.cn/products/ru/standard/24...
# 10  http://www.czce.com.cn/cn/sspz/jc/H770208index...
# 11                                                NaN
# 12  http://www.dce.com.cn/dalianshangpin/sspz/4871...
# 13  http://www.czce.com.cn/cn/sspz/czp/H770211inde...
# 14  http://www.dce.com.cn/dalianshangpin/sspz/4872...
# 15  http://www.dce.com.cn/dalianshangpin/sspz/4872...
# 16  https://finance.sina.com.cn/futures/quotes/A19...
# 17  http://www.dce.com.cn/dalianshangpin/sspz/ym/i...
# 18  http://www.czce.com.cn/cn/sspz/pg/H770221index...
# 19  http://www.czce.com.cn/cn/sspz/czy/H770206inde...
# 20  http://www.czce.com.cn/cn/sspz/bt/H770204index...
# 21  http://www.shfe.com.cn/products/cu/standard/90...
# 22  http://www.shfe.com.cn/products/al/\nhttps://f...
# 23  http://www.shfe.com.cn/products/zn/\nhttps://f...
# 24  http://www.dce.com.cn/dalianshangpin/sspz/4873...
# 25  http://www.dce.com.cn/dalianshangpin/sspz/4873...
# 26  http://www.dce.com.cn/dalianshangpin/sspz/4873...
# 27  http://www.czce.com.cn/cn/sspz/pta/H770205inde...
# 28  http://www.dce.com.cn/dalianshangpin/sspz/4872...
# 29  http://www.czce.com.cn/cn/sspz/mh/H770203index...
# 30  http://www.shfe.com.cn/products/ni/standard/91...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
#
#                                          最后交易日  \
# 0                                最后交易日后连续5个工作日
# 1                                          NaN
# 2                                          NaN
# 3                                合约交割月份的第5个交易日
# 4                               合约交割月份的第10个交易日
# 5                           合约交割月份15日(遇法定假日顺延)
# 6                                          NaN
# 7                           合约交割月份15日(遇法定假日顺延)
# 8                           合约交割月份15日(遇法定假日顺延)
# 9                                     合约月份的15日
# 10                              合约交割月份的第10个交易日
# 11                                         NaN
# 12                                         NaN
# 13                              合约交割月份的第10个交易日
# 14                              合约交割月份的第10个交易日
# 15                              合约交割月份的第10个交易日
# 16                                         NaN
# 17                              合约交割月份的第10个交易日
# 18                              合约交割月份的第10个交易日
# 19                              合约交割月份的第10个交易日
# 20                              合约交割月份的第10个交易日
# 21  合约月份的15日（遇国家法定节假日顺延，春节月份等最后交易日交易所可另行调整并通知）
# 22                          合约交割月份15日(遇法定假日顺延)
# 23                          合约交割月份15日(遇法定假日顺延)
# 24                              合约交割月份的第10个交易日
# 25                              合约交割月份的第10个交易日
# 26                              合约交割月份的第10个交易日
# 27                              合约交割月份的第10个交易日
# 28                              合约交割月份倒数第4个交易日
# 29                              合约交割月份的第10个交易日
# 30  合约月份的15日（遇国家法定节假日顺延，春节月份等最后交易日交易所可另行调整并通知）
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49                                         NaN
# 50                                         NaN
# 51                                         NaN
# 52                                         NaN
# 53                                         NaN
# 54                                         NaN
# 55                                         NaN
# 56                                         NaN
#
#                                        交易时间           涨跌停
# 0                                       NaN           NaN
# 1                                       NaN           NaN
# 2                                       NaN           NaN
# 3     上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 4     上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 5     上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 6                                       NaN           NaN
# 7     上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±6%
# 8     上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 9    上午9:00－11:30 ，下午1:30－3:00和交易所规定的其他交易时间   上一交易日结算价±3%
# 10    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 11                                      NaN           NaN
# 12                                      NaN           NaN
# 13    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 14    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 15    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 16                                      NaN           NaN
# 17    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 18  上午 9：00-11：30 下午 1：30-3：00及交易所规定的其他交易时间  上一个交易日结算价±5%
# 19    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 20    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 21   上午9:00－11:30 ，下午1:30－3:00和交易所规定的其他交易时间   上一交易日结算价±3%
# 22    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±3%
# 23    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 24    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 25    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 26    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 27    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 28    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±5%
# 29    上午9：00-11：30，下午1：30-3：00及交易所规定的其他交易时间   上一交易日结算价±4%
# 30    上午9:00-11:30，下午1:30-3:00和交易所规定的其他交易时间   上一交易日结算价±4%
# 31                                      NaN           NaN
# 32                                      NaN           NaN
# 33                                      NaN           NaN
# 34                                      NaN           NaN
# 35                                      NaN           NaN
# 36                                      NaN           NaN
# 37                                      NaN           NaN
# 38                                      NaN           NaN
# 39                                      NaN           NaN
# 40                                      NaN           NaN
# 41                                      NaN           NaN
# 42                                      NaN           NaN
# 43                                      NaN           NaN
# 44                                      NaN           NaN
# 45                                      NaN           NaN
# 46                                      NaN           NaN
# 47                                      NaN           NaN
# 48                                      NaN           NaN
# 49                                      NaN           NaN
# 50                                      NaN           NaN
# 51                                      NaN           NaN
# 52                                      NaN           NaN
# 53                                      NaN           NaN
# 54                                      NaN           NaN
# 55                                      NaN           NaN
# 56                                      NaN           NaN
#
# [57 rows x 24 columns]

# %%
pd.Series(futures_info.columns)
# Out:
# 0                               交易所
# 1                             品种大类别
# 2                             品种子类别
# 3                        Unnamed: 3
# 4                                品种
# 5                              收盘价格
# 6                              开盘价格
# 7                               最低价
# 8                               最高价
# 9                               成交量
# 10                      品种大类别（归纳定义）
# 11                             交易代码
# 12                 主力代号（截至20190804）
# 13               保证金（%）（截至20190804）
# 14                            一手保证金
# 15                             一手价值
# 16                              手续费
# 17    交易单位（contractunit）/手OR每点价值/乘数
# 18                      最小变动价位（元/吨）
# 19                             报价单位
# 20                           合约在线地址
# 21                            最后交易日
# 22                             交易时间
# 23                              涨跌停
# dtype: object

# %%
drop_ind = [1,2,3,10, 14, 15, 19, 20, 21, 22, 23]
left = futures_info.columns[drop_ind]
left
# Out:
# Index(['品种大类别', '品种子类别', 'Unnamed: 3', '品种大类别（归纳定义）', '一手保证金', '一手价值', '报价单位',
#        '合约在线地址', '最后交易日', '交易时间', '涨跌停'],
#       dtype='object')

# %% [markdown]
# ## 想办法在tushare里找到接口截取期货的日线数据

# %%
futures_info = futures_info.drop(columns = left)
futures_info.head()
# Out:
#        交易所       品种     收盘价格  开盘价格  最低价  最高价  成交量 交易代码  主力代号（截至20190804）  \
# 0  上海期货交易所       沪金   278.55   NaN  NaN  NaN  NaN   AU            1906.0
# 1  大连商品交易所       焦炭  1972.00   NaN  NaN  NaN  NaN    J            1909.0
# 2  大连商品交易所      铁矿石   514.00   NaN  NaN  NaN  NaN    I            2001.0
# 3  郑州商品交易所  动力煤（郑煤）   565.00   NaN  NaN  NaN  NaN   ZC            1909.0
# 4  大连商品交易所       焦煤  1193.00   NaN  NaN  NaN  NaN   JM            1909.0
#
#    保证金（%）（截至20190804）                                      手续费  \
# 0                 7.0                                    10元/手
# 1                 8.0                              成交金额的万分之0.6
# 2                 8.0  1月、5月、9月合约：成交金额万分之0.6；其它合约：成交金额的万分之0.06
# 3                 6.0                                     4元/手
# 4                 9.0                              成交金额的万分之0.6
#
#    交易单位（contractunit）/手OR每点价值/乘数 最小变动价位（元/吨）
# 0                         1000.0        0.05
# 1                          100.0         0.5
# 2                          100.0         0.5
# 3                          100.0         0.2
# 4                           60.0         0.5

# %%
futures_info.columns
# Out:
# Index(['交易所', '品种大类别', '品种子类别', 'Unnamed: 3', '品种', '收盘价格', '开盘价格', '最低价',
#        '最高价', '成交量', '品种大类别（归纳定义）', '交易代码', '主力代号（截至20190804）',
#        '保证金（%）（截至20190804）', '一手保证金', '一手价值', '手续费',
#        '交易单位（contractunit）/手OR每点价值/乘数', '最小变动价位（元/吨）', '报价单位', '合约在线地址',
#        '最后交易日', '交易时间', '涨跌停'],
#       dtype='object')

# %% [markdown]
# ## 查看主力合约代号  Main Contract

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
mc= futures_info[['交易所', '主力代号（截至20190804）']].drop_duplicates().dropna().sort_values('交易所')
mc['exchange'] = 'INE'
SHFE = mc.loc[mc['交易所'] == "上海期货交易所"].index
DCE  = mc.loc[mc['交易所'] == "大连商品交易所"].index
CZCE = mc.loc[mc['交易所'] == "郑州商品交易所"].index
mc.loc[SHFE,'exchange'] = "SHFE"
mc.loc[DCE, 'exchange'] = 'DCE'
mc.loc[CZCE,'exchange'] = 'CZCE'
mc = mc.rename(columns = {'主力代号（截至20190804）':'MainContract'})
mc.MainContract = mc.MainContract.astype(str).str[:4]
mc
# Out:
#            交易所 MainContract exchange
# 33  上海国际能源交易中心         1907      INE
# 0      上海期货交易所         1906     SHFE
# 5      上海期货交易所         1912     SHFE
# 6      上海期货交易所         1910     SHFE
# 8      上海期货交易所         1905     SHFE
# 9      上海期货交易所         1909     SHFE
# 21     上海期货交易所         1907     SHFE
# 1      大连商品交易所         1909      DCE
# 2      大连商品交易所         2001      DCE
# 3      郑州商品交易所         1909     CZCE
# 18     郑州商品交易所         1910     CZCE
# 20     郑州商品交易所         2001     CZCE

# %%
futures_info['交易所'].unique()
# Out:
# array(['上海期货交易所', '大连商品交易所', '郑州商品交易所', '上海国际能源交易中心', nan], dtype=object)

# %%
futures_info['品种'].unique()
# Out:
# array(['沪金', '焦炭', '铁矿石', '动力煤（郑煤）', '焦煤', '银', '螺纹', '热轧卷板', '沪锡', '橡胶',
#        '郑醇', '沥青', '豆粕', '菜籽粕（简称“菜粕”）', '豆油', '棕榈（油）', '黄大豆1号', '黄玉米',
#        '苹果', '菜籽油（简称“菜油”）（“郑油”）', '白砂糖(简称“白糖”）', '沪铜', '铝', '锌',
#        '线型低密度聚乙烯（塑料）', '聚氯乙烯（PVC）', '\t聚丙烯（PP）', '精对苯二甲酸（PTA）', '鸡蛋',
#        '棉花', '沪镍', '纸浆', '铅', '原油', '燃油', '玻璃', '乙二醇', '锰硅', '硅铁', '玉米淀粉',
#        nan, '淀粉'], dtype=object)

# %% [markdown]
# ## 交易新闻

# %%
ts.get_latest_news()
# Out:
# <urlopen error timed out>

# %% [markdown]
# ## 指数数据

# %%
ts.get_index()
# Out:
#       code    name  change        open    preclose       close        high  \
# 0   000001    上证指数    0.31   2798.4295   2811.1741   2819.9350   2823.3382
# 1   000002    Ａ股指数    0.31   2932.7967   2946.1803   2955.4296   2958.9879
# 2   000003    Ｂ股指数   -0.81    215.9379    215.9460    214.1933    215.9379
# 3   000008    综合指数    0.15   2596.1436   2609.1392   2613.1415   2617.3912
# 4   000009   上证380    0.47   4674.3871   4692.9609   4714.8630   4722.4962
# 5   000010   上证180    0.28   8062.2676   8099.5175   8121.9547   8132.8818
# 6   000011    基金指数    0.28   6111.6096   6126.6020   6144.0100   6152.9890
# 7   000012    国债指数    0.02    182.1254    182.1087    182.1488    182.1917
# 8   000016    上证50    0.14   2751.6937   2764.4883   2768.2616   2771.4343
# 9   000017     新综指    0.31   2364.7952   2375.5880   2383.0453   2385.9146
# 10  000300   沪深300    0.13   3777.7986   3797.3623   3802.3806   3807.3569
# 11  000905   中证500    0.92   5245.9247   5268.7497   5316.9707   5328.1204
# 12  399001    深证成指    0.51  10361.7660  10417.3740  10470.7940  10489.1340
# 13  399002    深成指R    0.52  12713.4220  12781.3640  12847.1940  12869.6970
# 14  399003    成份Ｂ指   -0.12   4849.2750   4847.9100   4842.1390   4853.7820
# 15  399004  深证100R   -0.09   5819.5510   5855.2660   5850.2890   5859.0590
# 16  399005    中小板指    0.50   6766.0310   6808.4260   6842.3640   6858.3690
# 17  399006    创业板指    1.56   1970.7320   1977.5150   2008.3880   2012.4630
# 18  399008   中小300    0.66   1294.5390   1301.9010   1310.4470   1313.6150
# 19  399100   新 指 数    0.43   7867.0090   7912.0130   7945.8100   7958.5650
# 20  399101    中小板综    0.45   9780.6250   9836.1430   9880.6770   9900.1130
# 21  399106    深证综指    0.48   1726.1710   1736.1340   1744.3910   1747.3100
# 22  399107    深证Ａ指    0.48   1806.1950   1816.6400   1825.3050   1828.3660
# 23  399108    深证Ｂ指   -0.26    834.6300    834.3910    832.2420    834.6300
# 24  399333    中小板R    0.50   7617.1970   7664.9250   7703.1330   7721.1520
# 25  399606    创业板R    1.56   2079.7090   2086.8660   2119.4470   2123.7470
#
#            low       volume     amount
# 0    2796.8388    203003773  2224.3260
# 1    2931.1336    202884288  2223.5897
# 2     214.1933       119485     0.7363
# 3    2595.9677     41952686   441.2754
# 4    4665.4110     42863087   511.3138
# 5    8059.2033     60050616   841.0392
# 6    6105.0175     89943187   301.6190
# 7     182.1254       597545     6.0387
# 8    2750.2919     23016379   417.7671
# 9    2363.4543    200864208  2127.6969
# 10   3774.5585     95947965  1471.6430
# 11   5238.4335    120742193  1220.6917
# 12  10346.1090  34870380920  3725.5576
# 13  12694.2130  13832665724  1894.5049
# 14   4815.9730      3934289     0.2225
# 15   5807.0560   3368973227   654.2108
# 16   6747.7590  17092830833  1699.2750
# 17   1968.2530   9438672610  1289.5913
# 18   1291.9130   8951506764  1080.1640
# 19   7854.1460  34212925564  3705.6926
# 20   9762.9730  17092830833  1699.2750
# 21   1723.4720  34870380920  3725.5576
# 22   1803.3770  34856590893  3725.1057
# 23    828.7830     13790027     0.4519
# 24   7596.6270   3638393853   582.0254
# 25   2077.0930   1855063038   442.4153

# %% [markdown]
# ## 期货合约信息表

# %%
print(">>>>>>>>>>>>> 获取期货合约信息表")
print("接口：\tfut_basic\n描述:\t获取期货合约列表数据")
print("可选参数：")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
print("\tfut_type\t|\t合约类型 (1->普通合约; 2->主力与连续合约 默认取全部)")
# Out:
# >>>>>>>>>>>>> 获取期货合约信息表
# 接口：	fut_basic
# 描述:	获取期货合约列表数据
# 可选参数：
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心
# 	fut_type	|	合约类型 (1->普通合约; 2->主力与连续合约 默认取全部)

# %%
pro = ts.pro_api(token)
futures_contract= pro.fut_basic(exchange='INE', fut_type='1', fields='ts_code,symbol,name,list_date,delist_date')

# %%
print("\t|合约代码|交易标识|中文简称|上市日期|最后交易日期|")
print(futures_contract)
# Out:
# 	|合约代码|交易标识|中文简称|上市日期|最后交易日期|
#        ts_code  symbol      name list_date delist_date
# 0   SC2006.INE  SC2006    原油2006  20180326    20200529
# 1   SC2009.INE  SC2009    原油2009  20180326    20200831
# 2   SC1907.INE  SC1907    原油1907  20180702    20190628
# 3   SC1911.INE  SC1911    原油1911  20181101    20191031
# 4   SC2002.INE  SC2002    原油2002  20190128    20200116
# 5   NR2008.INE  NR2008  20号胶2008  20190816    20200817
# 6   NR2010.INE  NR2010  20号胶2010  20191016    20201015
# 7   SC2212.INE  SC2212    原油2212  20191202    20221130
# 8   NR2012.INE  NR2012  20号胶2012  20191217    20201215
# 9   NR2101.INE  NR2101  20号胶2101  20200116    20210115
# 10  SC2303.INE  SC2303    原油2303  20200302    20230228
# 11  SC2104.INE  SC2104    原油2104  20200401    20210331
# 12  NR2104.INE  NR2104  20号胶2104  20200416    20210415
# 13  SC1809.INE  SC1809    原油1809  20180326    20180831
# 14  SC1812.INE  SC1812    原油1812  20180326    20181130
# 15  SC1903.INE  SC1903    原油1903  20180326    20190228
# 16  SC1906.INE  SC1906    原油1906  20180326    20190531
# 17  SC1909.INE  SC1909    原油1909  20180326    20190830
# 18  SC1912.INE  SC1912    原油1912  20180326    20191129
# 19  SC2003.INE  SC2003    原油2003  20180326    20200228
# 20  SC1810.INE  SC1810    原油1810  20180326    20180920
# 21  SC2012.INE  SC2012    原油2012  20180326    20201130
# 22  SC2103.INE  SC2103    原油2103  20180326    20210226
# 23  SC2106.INE  SC2106    原油2106  20180601    20210531
# 24  SC1908.INE  SC1908    原油1908  20180801    20190731
# 25  SC2109.INE  SC2109    原油2109  20180903    20210831
# 26  SC1910.INE  SC1910    原油1910  20180921    20190923
# 27  SC2112.INE  SC2112    原油2112  20181203    20211130
# 28  SC2203.INE  SC2203    原油2203  20190301    20220228
# 29  SC2004.INE  SC2004    原油2004  20190401    20200331
# 30  SC2206.INE  SC2206    原油2206  20190603    20220531
# 31  SC2007.INE  SC2007    原油2007  20190701    20200630
# 32  SC2008.INE  SC2008    原油2008  20190801    20200731
# 33  NR2006.INE  NR2006  20号胶2006  20190812    20200615
# 34  NR2007.INE  NR2007  20号胶2007  20190812    20200715
# 35  NR2009.INE  NR2009  20号胶2009  20190917    20200915
# 36  SC2010.INE  SC2010    原油2010  20190924    20200923
# 37  NR2011.INE  NR2011  20号胶2011  20191118    20201116
# 38  SC2102.INE  SC2102    原油2102  20200117    20210129
# 39  NR2103.INE  NR2103  20号胶2103  20200317    20210315
# 40  SC1811.INE  SC1811    原油1811  20180326    20181031
# 41  SC1901.INE  SC1901    原油1901  20180326    20181228
# 42  SC1902.INE  SC1902    原油1902  20180326    20190125
# 43  SC1904.INE  SC1904    原油1904  20180402    20190329
# 44  SC1905.INE  SC1905    原油1905  20180502    20190430
# 45  SC2001.INE  SC2001    原油2001  20190102    20191220
# 46  SC2005.INE  SC2005    原油2005  20190506    20200430
# 47  NR2002.INE  NR2002  20号胶2002  20190812    20200217
# 48  NR2003.INE  NR2003  20号胶2003  20190812    20200316
# 49  NR2004.INE  NR2004  20号胶2004  20190812    20200415
# 50  NR2005.INE  NR2005  20号胶2005  20190812    20200515
# 51  SC2209.INE  SC2209    原油2209  20190902    20220831
# 52  SC2011.INE  SC2011    原油2011  20191101    20201030
# 53  SC2101.INE  SC2101    原油2101  20191223    20201224
# 54  NR2102.INE  NR2102  20号胶2102  20200218    20210205

# %% [markdown]
# ## 期货交易日历

# %%
print(">>>>>>>>>>>>> 获取期货交易日历")
print("接口：\ttrade_cal\n描述:\t获取各大期货交易所交易日历数据")
print("可选参数：")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
print("\tstart_date\t|\t开始日期")
print("\tend_date\t|\t结束日期")
print("\tis_open\t\t|\t是否交易【0->休市; 1->交易】")
# Out:
# >>>>>>>>>>>>> 获取期货交易日历
# 接口：	trade_cal
# 描述:	获取各大期货交易所交易日历数据
# 可选参数：
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心
# 	start_date	|	开始日期
# 	end_date	|	结束日期
# 	is_open		|	是否交易【0->休市; 1->交易】

# %%
pro = ts.pro_api(token)
futures_trade_cal_DCE = pro.trade_cal(exchange = "DCE")

# %%
print("\t|交易所|日历日期|是否交易|")
print(futures_trade_cal_DCE)
# Out:
# 	|交易所|日历日期|是否交易|
#       exchange  cal_date  is_open
# 0          DCE  19930301        1
# 1          DCE  19930302        1
# 2          DCE  19930303        1
# 3          DCE  19930304        1
# 4          DCE  19930305        1
# ...        ...       ...      ...
# 10163      DCE  20201227        0
# 10164      DCE  20201228        1
# 10165      DCE  20201229        1
# 10166      DCE  20201230        1
# 10167      DCE  20201231        1
#
# [10168 rows x 3 columns]

# %% [markdown]
# ## 期货日线行情

# %%
print(">>>>>>>>>>>>> 获取期货日线行情")
print("接口：\tfut_daily\n描述:\t获取期货日线行情数据")
print("可选参数：")
print("\ttrade_date\t|\t交易日期")
print("\tts_code\t\t|\t合约代码")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
print("\tstart_date\t|\t开始日期")
print("\tend_date\t|\t结束日期")
# Out:
# >>>>>>>>>>>>> 获取期货日线行情
# 接口：	fut_daily
# 描述:	获取期货日线行情数据
# 可选参数：
# 	trade_date	|	交易日期
# 	ts_code		|	合约代码
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心
# 	start_date	|	开始日期
# 	end_date	|	结束日期

# %%
pro = ts.pro_api(token)
futures_daily = pro.fut_daily(ts_code = "CU1811.SHF", start_date = "20180101", end_date = "20191231")
daily_columns = "合约代码|交易日期|昨日收盘价|昨日结算价|开盘价|最高价|最低价|收盘价|结算价|收盘价-昨日结算价|结算价-昨日结算价|成交量|成交金额（万)|持仓量|持仓量变化".split("|")
for c in daily_columns: print("", c, end = "|")
futures_daily
# Out:
#  合约代码| 交易日期| 昨日收盘价| 昨日结算价| 开盘价| 最高价| 最低价| 收盘价| 结算价| 收盘价-昨日结算价| 结算价-昨日结算价| 成交量| 成交金额（万)| 持仓量| 持仓量变化|
#         ts_code trade_date  pre_close  pre_settle     open     high      low  \
# 0    CU1811.SHF   20181115    48750.0     48840.0  48840.0  49350.0  48470.0
# 1    CU1811.SHF   20181114    49030.0     48830.0  49070.0  49240.0  48720.0
# 2    CU1811.SHF   20181113    48900.0     49030.0  48910.0  49040.0  48700.0
# 3    CU1811.SHF   20181112    49270.0     49340.0  49130.0  49200.0  48860.0
# 4    CU1811.SHF   20181109    49440.0     49500.0  49340.0  49530.0  49120.0
# ..          ...        ...        ...         ...      ...      ...      ...
# 207  CU1811.SHF   20180108    56200.0     56300.0  56010.0  56070.0  55750.0
# 208  CU1811.SHF   20180105    56650.0     56590.0  56600.0  56600.0  56090.0
# 209  CU1811.SHF   20180104    56200.0     56210.0  56110.0  56660.0  56070.0
# 210  CU1811.SHF   20180103    56610.0     56490.0  56540.0  56580.0  56110.0
# 211  CU1811.SHF   20180102    56820.0     57000.0  56870.0  56870.0  56390.0
#
#        close   settle  change1  change2      vol     amount       oi  oi_chg
# 0    49300.0  49030.0    460.0    190.0   3800.0   93169.60   7210.0 -1640.0
# 1    48750.0  48840.0    -80.0     10.0  14500.0  354162.25   8850.0 -7260.0
# 2    49030.0  48830.0      0.0   -200.0  17270.0  421721.70  16110.0 -6830.0
# 3    48900.0  49030.0   -440.0   -310.0  27710.0  679447.85  22940.0 -7160.0
# 4    49270.0  49340.0   -230.0   -160.0  22530.0  555910.15  30100.0 -4700.0
# ..       ...      ...      ...      ...      ...        ...      ...     ...
# 207  55910.0  55840.0   -390.0   -460.0     84.0    2345.53   1412.0    48.0
# 208  56200.0  56300.0   -390.0   -290.0     46.0    1295.05   1364.0    20.0
# 209  56650.0  56590.0    440.0    380.0     44.0    1245.12   1344.0     0.0
# 210  56200.0  56210.0   -290.0   -280.0    166.0    4666.23   1344.0     0.0
# 211  56610.0  56490.0   -390.0   -510.0     64.0    1807.72   1344.0     2.0
#
# [212 rows x 15 columns]

# %%
futures_daily[''] = futures_daily.ts_code.str[2:6]
# Out:
# 0      1811
# 1      1811
# 2      1811
# 3      1811
# 4      1811
#        ...
# 207    1811
# 208    1811
# 209    1811
# 210    1811
# 211    1811
# Name: ts_code, Length: 212, dtype: object

# %% [markdown]
# ## 每日成交持仓排名

# %%
print(">>>>>>>>>>>>> 获取每日成交持仓排名")
print("接口：\tfut_holding\n描述:\t获取每日成交持仓排名数据")
print("\ttrade_date\t|\t交易日期")
print("\tsymbol\t\t|\t合约或产品代码\t[注：（trade_date/symbol至少输入一个参数）]")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
print("\tstart_date\t|\t开始日期")
print("\tend_date\t|\t结束日期")
# Out:
# >>>>>>>>>>>>> 获取每日成交持仓排名
# 接口：	fut_holding
# 描述:	获取每日成交持仓排名数据
# 	trade_date	|	交易日期
# 	symbol		|	合约或产品代码	[注：（trade_date/symbol至少输入一个参数）]
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心
# 	start_date	|	开始日期
# 	end_date	|	结束日期

# %%
futures_hold = pro.fut_holding(trade_date = '20191231', symbol = "B")
print(f"共有{len(futures_hold)}条数据")
hold_columns = "交易日期|Symbol|期货公司会员简称|成交量|成交量变化|持买仓量|持买仓量变化|持卖仓量|持卖仓量变化".split("|")
for c in hold_columns: print("", c, end = " |")
futures_hold.head()
# Out:
# 共有36条数据
# |交易日期|Symbol|期货公司会员简称|成交量|成交量变化|持买仓量|持买仓量变化|持卖仓量|持卖仓量变化|
#   trade_date symbol broker      vol  vol_chg  long_hld  long_chg  short_hld  \
# 0   20191231      B   一德期货      NaN      NaN       NaN       NaN      835.0
# 1   20191231      B   上海中期  29080.0  26394.0    2380.0  -14496.0     2315.0
# 2   20191231      B   东方财富    939.0  -1082.0       NaN       NaN        NaN
# 3   20191231      B   东证期货  19121.0   3692.0    1461.0     117.0      379.0
# 4   20191231      B   中信建投      NaN      NaN       NaN       NaN      727.0
#
#    short_chg
# 0      328.0
# 1   -14386.0
# 2        NaN
# 3       40.0
# 4     -304.0

# %% [markdown]
# ## 仓单日报

# %%
print(">>>>>>>>>>>>> 获取仓单日报")
print("接口：\tfut_wsr\n描述:\t获取仓单日报数据，了解各仓库/厂库的仓单变化")
print("\ttrade_date\t|\t交易日期")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
# Out:
# >>>>>>>>>>>>> 获取仓单日报
# 接口：	fut_wsr
# 描述:	获取仓单日报数据，了解各仓库/厂库的仓单变化
# 	trade_date	|	交易日期
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心

# %%
futures_wsr = pro.fut_wsr(trade_date ="20200214", exchange = "DCE")#symbol = "ZN")
wsr_columns = "交易日期|产品代码|产品名称|仓库名称|昨日仓单量|今日仓单量|增减量|单位".split("|")
for c in wsr_columns: print("", c, end = " |")
futures_wsr
# Out:
# |交易日期|产品代码|产品名称|仓库名称|昨日仓单量|今日仓单量|增减量|单位|
#    trade_date symbol fut_name warehouse  pre_vol    vol  vol_chg unit
# 0    20200214     ZN        锌      上海裕强      100   4791     4691    吨
# 1    20200214     ZN        锌      上港物流     3296   3296        0    吨
# 2    20200214     ZN        锌    上港物流苏州        0      0        0    吨
# 3    20200214     ZN        锌      中储吴淞        0      0        0    吨
# 4    20200214     ZN        锌      中储大场        0      0        0    吨
# 5    20200214     ZN        锌      中储晟世      778    778        0    吨
# 6    20200214     ZN        锌      中金圣源    11099  11099        0    吨
# 7    20200214     ZN        锌      全胜物流     9515   9515        0    吨
# 8    20200214     ZN        锌      南储仓储    23064  23064        0    吨
# 9    20200214     ZN        锌    国储837处        0      0        0    吨
# 10   20200214     ZN        锌      国储天威        0      0        0    吨
# 11   20200214     ZN        锌    国能物流常州     5810   5810        0    吨
# 12   20200214     ZN        锌   外运华东张华浜        0      0        0    吨
# 13   20200214     ZN        锌     宁波九龙仓        0      0        0    吨
# 14   20200214     ZN        锌  广储830三水西        0      0        0    吨
# 15   20200214     ZN        锌      康运萧山        0      0        0    吨
# 16   20200214     ZN        锌      无锡国联        0      0        0    吨
# 17   20200214     ZN        锌      浙江康运        0      0        0    吨
# 18   20200214     ZN        锌     百金汇物流        0      0        0    吨
# 19   20200214     ZN        锌      裕强闵行        0      0        0    吨

# %% [markdown]
# ## 结算参数

# %%
print(">>>>>>>>>>>>> 获取结算参数")
print("接口：\tfut_settle\n描述:\t获取每日结算参数数据，包括交易和交割费率等")
print("\ttrade_date\t|\t交易日期")
print("\tts_code\t\t|\t合约代码")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
# Out:
# >>>>>>>>>>>>> 获取结算参数
# 接口：	fut_settle
# 描述:	获取每日结算参数数据，包括交易和交割费率等
# 	trade_date	|	交易日期
# 	ts_code		|	合约代码
# 	exchange	|	CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心

# %%
futures_settle = pro.fut_settle(trade_date = "20190308", exchange = "CZCE")
settle_columns = "合约代码|交易日期|结算价|交易手续费率|交易手续费|交割手续费率|买套保交易保证金率|卖套保交易保证金率|买投机保证金率|卖投机保证金率"
settle_columns = settle_columns.split("|")
for c in settle_columns: print("",c, end = " |") 
futures_settle
# Out:
#  合约代码 | 交易日期 | 结算价 | 交易手续费率 | 交易手续费 | 交割手续费率 | 买套保交易保证金率 | 卖套保交易保证金率 | 买投机保证金率 | 卖投机保证金率 |
#         ts_code trade_date   settle trading_fee_rate  trading_fee  \
# 0    AP1903.ZCE   20190308  11223.0             None         20.0
# 1    AP1905.ZCE   20190308  11330.0             None         20.0
# 2    AP1907.ZCE   20190308  11607.0             None         20.0
# 3    AP1910.ZCE   20190308   8326.0             None          5.0
# 4    AP1911.ZCE   20190308   8305.0             None          5.0
# ..          ...        ...      ...              ...          ...
# 144  ZC1908.ZCE   20190308    597.8             None          4.0
# 145  ZC1909.ZCE   20190308    582.0             None          4.0
# 146  ZC1910.ZCE   20190308    586.8             None          4.0
# 147  ZC1911.ZCE   20190308    581.6             None          0.5
# 148  ZC1912.ZCE   20190308    590.6             None          4.0
#
#      delivery_fee b_hedging_margin_rate s_hedging_margin_rate  \
# 0            10.0                  None                  None
# 1            10.0                  None                  None
# 2            10.0                  None                  None
# 3            10.0                  None                  None
# 4            10.0                  None                  None
# ..            ...                   ...                   ...
# 144        5000.0                  None                  None
# 145        5000.0                  None                  None
# 146        5000.0                  None                  None
# 147        5000.0                  None                  None
# 148        5000.0                  None                  None
#
#      long_margin_rate  short_margin_rate
# 0                0.20               0.20
# 1                0.11               0.11
# 2                0.20               0.20
# 3                0.08               0.08
# 4                0.08               0.08
# ..                ...                ...
# 144              0.08               0.08
# 145              0.08               0.08
# 146              0.08               0.08
# 147              0.08               0.08
# 148              0.08               0.08
#
# [149 rows x 10 columns]

# %% [markdown]
# ## 南华期货指数日线行情

# %%
print(">>>>>>>>>>>>> 获取南华期货指数日线行情")
print("接口：\tindex_daily\n描述:\t获取南华指数每日行情，指数行情也可以通过通用行情接口获取数据．[https://tushare.pro/document/2?doc_id=109]")
print("\ttrade_date\t|\t交易日期")
print("\tts_code\t\t|\t合约代码")
futures_index_daily = pro.index_daily(ts_code = "CU.NH", start_date='20200101', end_date='20201201')
ind_dai_columns = "TS指数代码，交易日期，收盘点位，开盘点位，最高点位，最低点位，昨日收盘点，涨跌点，涨跌幅，成交量，成交额（千）".split("，")
for i in ind_dai_columns: print("", i, end = " |")
futures_index_daily

# %% [markdown]
# ## 期货主力与连续合约

# %%
print(">>>>>>>>>>>>> 获取期货主力与连续合约")
print("接口：\tfut_mapping\n描述:\t获取期货主力（或连续）合约与月合约映射数据")
print("\ttrade_date\t|\t交易日期")
print("\tts_code\t\t|\t合约代码")
futures_mapping = pro.fut_mapping(ts_code = "TF.CFX")
mapping_columns = "连续合约代码。起始日期。期货合约代码".split("。")
for i in mapping_columns: print("", i, end = " |")
futures_mapping

# %% [markdown]
# ## 期货主要品种交易周报

# %%
print(">>>>>>>>>>>>> 获取期货主要品种交易周报")
print("接口：\tfut_weekly_detail\n描述:\t获取期货交易所主要品种每周交易统计信息，数据从2010年3月开始")
print("\tweek\t\t|\t周期（每年第几周，e.g. 202001 表示2020第1周）")
print("\tprd\t\t|\t期货品种（支持多品种输入，逗号分隔）")
print("\tstart_week\t|\t开始周期")
print("\tend_week\t|\t结束周期")
print("\texchange\t|\tCFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心")
print("\tfields\t\t|\t提取的字段，e.g. fields='prd,name,vol'")
all_columns = "exchange|prd|name|vol|vol_yoy|amount|amount_yoy|cumvol|cumvol_yoy|cumamt|cumamt_yoy|open_interest|interest_wow|mc_close|close_wow|week|week_date".split("|")
print("可选择输出：")
for c in range(len(all_columns)): print(f"{c}:{all_columns[c]}", end = " |")
futures_weekly_detail = pro.fut_weekly_detail(prd = "CU", start_week = "202001", end_week = "202003", fields = all_columns[:5])
futures_weekly_detail
